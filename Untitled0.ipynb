# %% [markdown]
# <a href="https://colab.research.google.com/github/Deep-KALYAN/Forum/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
path1='/content/sample_data/CA.csv'
path2='/content/sample_data/Marketing.csv'
ca = pd.read_csv(path1, sep=',' )
marketing = pd.read_csv(path2, sep=',' )
ca
# Out:
#            Date   Day_Name  Visitors  Revenue
# 0    09/11/2020     Monday       707     5211
# 1    10/11/2020    Tuesday      1455    10386
# 2    11/11/2020  Wednesday      1520    12475
# 3    12/11/2020   Thursday      1726    14414
# 4    13/11/2020     Friday      2134    20916
# ..          ...        ...       ...      ...
# 114  03/03/2021  Wednesday      1068     8223
# 115  04/03/2021   Thursday      1976    16727
# 116  05/03/2021     Friday      1806    15474
# 117  06/03/2021   Saturday      1621    12850
# 118  07/03/2021     Sunday      1001     6681
#
# [119 rows x 4 columns]

# %%
marketing
# Out:
#            Date  Marketing Spend           Promo
# 0    22/12/2020      1024.500000   Promotion Red
# 1    23/12/2020      1181.700000  Promotion Blue
# 2    24/12/2020      1955.000000        No Promo
# 3    25/12/2020      2336.777778  Promotion Blue
# 4    26/12/2020      4535.375000  Promotion Blue
# ..          ...              ...             ...
# 119  05/05/2021      1119.600000        No Promo
# 120  06/05/2021      2067.888889   Promotion Red
# 121  07/05/2021      1450.200000        No Promo
# 122  08/05/2021      1121.875000        No Promo
# 123  09/05/2021       871.000000        No Promo
#
# [124 rows x 3 columns]

# %%
marketing.shape
# Out:
# (124, 3)

# %%
ca.shape
# Out:
# (119, 4)

# %% [markdown]
# # Nouvelle section

# %%
#marketing['Date'].nunique()
ca['Date'].nunique()
# Out:
# 119

# %%
df=pd.merge(marketing,ca,on='Date',how='outer')
print(df)
# Out:
#            Date  Marketing Spend           Promo   Day_Name  Visitors  Revenue
# 0    01/01/2021      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1    01/02/2021              NaN             NaN     Monday    1407.0  10479.0
# 2    01/03/2021              NaN             NaN     Monday    1786.0  13212.0
# 3    01/04/2021      2921.000000  Promotion Blue        NaN       NaN      NaN
# 4    01/05/2021       805.636364        No Promo        NaN       NaN      NaN
# ..          ...              ...             ...        ...       ...      ...
# 170  30/11/2020              NaN             NaN     Monday    1541.0   9144.0
# 171  30/12/2020       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# 172  31/01/2021      1035.111111        No Promo     Sunday    1582.0   9316.0
# 173  31/03/2021      1869.625000   Promotion Red        NaN       NaN      NaN
# 174  31/12/2020              NaN             NaN   Thursday    2295.0  19280.0
#
# [175 rows x 6 columns]

# %%
#df.dtypes
print("Valeurs manquantes par colonne :")
print(df.isnull().sum())

for col in df.columns:
    if df[col].dtype == 'object':
        df[col].fillna('Inconnu', inplace=True)
    elif df[col].dtype == 'float64':
        df[col].fillna(0, inplace=True)

print("Données après nettoyage :")
print(df)
# Out:
# Valeurs manquantes par colonne :
# Date                0
# Marketing Spend    51
# Promo              51
# Day_Name           56
# Visitors           56
# Revenue            56
# dtype: int64
# Données après nettoyage :
#            Date  Marketing Spend           Promo   Day_Name  Visitors  Revenue
# 0    01/01/2021      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1    01/02/2021         0.000000         Inconnu     Monday    1407.0  10479.0
# 2    01/03/2021         0.000000         Inconnu     Monday    1786.0  13212.0
# 3    01/04/2021      2921.000000  Promotion Blue    Inconnu       0.0      0.0
# 4    01/05/2021       805.636364        No Promo    Inconnu       0.0      0.0
# ..          ...              ...             ...        ...       ...      ...
# 170  30/11/2020         0.000000         Inconnu     Monday    1541.0   9144.0
# 171  30/12/2020       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'], format='%d/%m/%Y',errors='coerce')
print(df)
print('Valeurs manquantes par colonne')
print(df.isnull().sum())
# Out:
#           Date  Marketing Spend           Promo   Day_Name  Visitors  Revenue
# 0   2021-01-01      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1   2021-02-01         0.000000         Inconnu     Monday    1407.0  10479.0
# 2   2021-03-01         0.000000         Inconnu     Monday    1786.0  13212.0
# 3   2021-04-01      2921.000000  Promotion Blue    Inconnu       0.0      0.0
# 4   2021-05-01       805.636364        No Promo    Inconnu       0.0      0.0
# ..         ...              ...             ...        ...       ...      ...
# 170 2020-11-30         0.000000         Inconnu     Monday    1541.0   9144.0
# 171 2020-12-30       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# 172 2021-01-31      1035.111111        No Promo     Sunday    1582.0   9316.0
# 173 2021-03-31      1869.625000   Promotion Red    Inconnu       0.0      0.0
# 174 2020-12-31         0.000000         Inconnu   Thursday    2295.0  19280.0
#
# [175 rows x 6 columns]
# ...

# %%
df.rename(columns={'Day_Name': 'Day'}, inplace=True)
print(df)
# Out:
#           Date  Marketing Spend           Promo        Day  Visitors  Revenue
# 0   2021-01-01      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1   2021-02-01         0.000000         Inconnu     Monday    1407.0  10479.0
# 2   2021-03-01         0.000000         Inconnu     Monday    1786.0  13212.0
# 3   2021-04-01      2921.000000  Promotion Blue    Inconnu       0.0      0.0
# 4   2021-05-01       805.636364        No Promo    Inconnu       0.0      0.0
# ..         ...              ...             ...        ...       ...      ...
# 170 2020-11-30         0.000000         Inconnu     Monday    1541.0   9144.0
# 171 2020-12-30       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# 172 2021-01-31      1035.111111        No Promo     Sunday    1582.0   9316.0
# 173 2021-03-31      1869.625000   Promotion Red    Inconnu       0.0      0.0
# 174 2020-12-31         0.000000         Inconnu   Thursday    2295.0  19280.0
#
# [175 rows x 6 columns]

# %%
df['Mois'] = df['Date'].dt.month
print(df)
# Out:
#           Date  Marketing Spend           Promo        Day  Visitors  Revenue  \
# 0   2021-01-01      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1   2021-02-01         0.000000         Inconnu     Monday    1407.0  10479.0
# 2   2021-03-01         0.000000         Inconnu     Monday    1786.0  13212.0
# 3   2021-04-01      2921.000000  Promotion Blue    Inconnu       0.0      0.0
# 4   2021-05-01       805.636364        No Promo    Inconnu       0.0      0.0
# ..         ...              ...             ...        ...       ...      ...
# 170 2020-11-30         0.000000         Inconnu     Monday    1541.0   9144.0
# 171 2020-12-30       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# 172 2021-01-31      1035.111111        No Promo     Sunday    1582.0   9316.0
# 173 2021-03-31      1869.625000   Promotion Red    Inconnu       0.0      0.0
# 174 2020-12-31         0.000000         Inconnu   Thursday    2295.0  19280.0
#
#      Mois
# 0       1
# ...

# %%
df.describe()
#Le site fonctionne bien en début d'année d'où la moyenne de l'occurence de mois qui est plus proche de 5 que de 6,
#et aussi marche très bien en fin d'année car le quatrième quartile commence en novembre au lieu de septembre dans une distribution normale
# Out:
#                                 Date  Marketing Spend     Visitors  \
# count                            175       175.000000   175.000000
# mean   2021-02-05 05:12:41.142857216       968.214414  1133.891429
# min              2020-11-09 00:00:00         0.000000     0.000000
# 25%              2020-12-22 12:00:00         0.000000     0.000000
# 50%              2021-02-04 00:00:00       871.000000  1328.000000
# 75%              2021-03-21 00:00:00      1437.444444  1812.500000
# max              2021-05-09 00:00:00      4535.375000  4139.000000
# std                              NaN       859.872817   891.643526
#
#             Revenue        Mois
# count    175.000000  175.000000
# mean    8839.560000    5.337143
# min        0.000000    1.000000
# 25%        0.000000    2.000000
# 50%     9067.000000    4.000000
# 75%    12923.000000   11.000000
# max    36283.000000   12.000000
# std     7868.416806    4.273084

# %%
df['Promo'].nunique()
#le nombre de valeurs distinctes dans la colonne 'Promo' est de 4
# Out:
# 4

# %%
df_filtered = df[(df['Day'] == 'Monday') & (df['Marketing Spend'] > 1200)]
print(df_filtered)
# Out:
#           Date  Marketing Spend           Promo     Day  Visitors  Revenue  \
# 140 2021-01-25         1365.625  Promotion Blue  Monday    1430.0  10925.0
#
#      Mois
# 140     1

# %%
camax = df.loc[df['Revenue'].idxmax()]
print(camax)
# Out:
# Date               2020-12-26 00:00:00
# Marketing Spend               4535.375
# Promo                   Promotion Blue
# Day                           Saturday
# Visitors                        2678.0
# Revenue                        36283.0
# Mois                                12
# Name: 151, dtype: object

# %%
Calculschiffre_affaire_total = df['Revenue'].sum()
depenses_marketing_min = df['Marketing Spend'].min()
visiteurs_moyenne = df['Visitors'].mean()
print("CA TOTAL : ",Calculschiffre_affaire_total)
print("Depenses minimum :",depenses_marketing_min)
print("Nb visiteurs moyen : ",visiteurs_moyenne)
print(df)
# Out:
# CA TOTAL :  1546923.0
# Depenses minimum : 0.0
# Nb visiteurs moyen :  1133.8914285714286
#           Date  Marketing Spend           Promo        Day  Visitors  Revenue  \
# 0   2021-01-01      1948.000000  Promotion Blue     Friday    2032.0  21428.0
# 1   2021-02-01         0.000000         Inconnu     Monday    1407.0  10479.0
# 2   2021-03-01         0.000000         Inconnu     Monday    1786.0  13212.0
# 3   2021-04-01      2921.000000  Promotion Blue    Inconnu       0.0      0.0
# 4   2021-05-01       805.636364        No Promo    Inconnu       0.0      0.0
# ..         ...              ...             ...        ...       ...      ...
# 170 2020-11-30         0.000000         Inconnu     Monday    1541.0   9144.0
# 171 2020-12-30       918.000000   Promotion Red  Wednesday    1328.0   9180.0
# 172 2021-01-31      1035.111111        No Promo     Sunday    1582.0   9316.0
# 173 2021-03-31      1869.625000   Promotion Red    Inconnu       0.0      0.0
# ...

# %%
visiteurs_par_mois = df.groupby('Mois')['Visitors'].sum()
print(visiteurs_par_mois)
mois_max = visiteurs_par_mois.idxmax()
print(f"Le mois avec le plus de visiteurs est le {mois_max}e de l'année")
# Out:
# Mois
# 1     52694.0
# 2     45449.0
# 3     10354.0
# 4         0.0
# 5         0.0
# 11    35092.0
# 12    54842.0
# Name: Visitors, dtype: float64
# Le mois avec le plus de visiteurs est le 12e de l'année

# %%
avg_revenue = df['Revenue'].mean()
avg_marketing_spend = df['Marketing Spend'].mean()
avg_visitors = df['Visitors'].mean()
print(avg_revenue)
print(avg_marketing_spend)
print(avg_visitors)
# Out:
# 8839.56
# 968.214414144
# 1133.8914285714286

# %%
promo_averages = df.groupby('Promo')[['Revenue', 'Marketing Spend', 'Visitors']].mean()
print(promo_averages)
# Out:
#                      Revenue  Marketing Spend     Visitors
# Promo
# Inconnu         13382.372549         0.000000  1709.803922
# No Promo         5386.333333      1093.127045   832.882353
# Promotion Blue  10658.857143      1884.626378  1134.771429
# Promotion Red    5701.552632      1255.950525   764.131579

# %%
plt.plot(df['Date'], df['Visitors'], label='Visitors')
plt.xlabel('Mois')
plt.ylabel('Visitors')
plt.title('Visitors par mois')
plt.legend()
plt.grid(True)
plt.show()

# %%
plt.plot(df_filtré['Date'], df_filtré['Revenue'])
plt.xlabel('Date')
plt.ylabel('Revenue')
plt.title('Revenus par Date')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-109-154ab4ddc7e9> in <cell line: 0>()
# ----> 1 plt.plot(df_filtré['Date'], df_filtré['Revenue'])
#       2 plt.xlabel('Date')
#       3 plt.ylabel('Revenue')
#       4 plt.title('Revenus par Date')
#       5 plt.xticks(rotation=45)
#
# NameError: name 'df_filtré' is not defined
